# %% [markdown]
# <a href="https://colab.research.google.com/github/delazaro/Patrones/blob/main/InvCorta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib
import pandas
import seaborn
import sympy

# %clear
print('hello word')


import matplotlib.pyplot as plt
import matplotlib.lines as lines
  
  
fig = plt.figure()
fig.add_artist(lines.Line2D([0, 1, 0.5], [0, 1, 0.3]))
fig.add_artist(lines.Line2D([0, 1, 0.5], [1, 0, 0.2]))
  
plt.title('matplotlib.pyplot.figure() Example\n',
                fontsize = 14, fontweight ='bold')
  
plt.show()

plt.title('matplotlib.pyplot.figure() Example\n',
                fontsize = 40, fontweight ='bold')


from IPython.display import display, Math

print('EJEMPLO DE LATEX ')

a = 'a'
b = 3
P = 'P'
V = 'V'
display(Math(r'Dims: {}x{}m \\ Area: {}m^2 \\ Volume: {}m^3'.format(a, round(b,2), P, V)))
# Out:
# hello word
# EJEMPLO DE LATEX
# $$Dims: ax3m \\ Area: Pm^2 \\ Volume: Vm^3$$
